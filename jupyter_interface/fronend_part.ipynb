# %%
# Import the necessary function from the script
from backend_part import generate_numbers

# Import matplotlib for plotting
import matplotlib.pyplot as plt

# Generate numbers using the imported function
numbers = generate_numbers(1, 10)

# Plotting the generated numbers
plt.figure(figsize=(10, 5))
plt.plot(numbers, marker='o')
plt.title('Generated Numbers')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()
